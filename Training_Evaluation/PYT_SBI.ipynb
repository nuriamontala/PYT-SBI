# %% [markdown]
# <a href="https://colab.research.google.com/github/nuriamontala/PYT-SBI/blob/main/PYT_SBI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torch_geometric.data import Data
import numpy as np

# List of standard amino acids
AMINO_ACIDS = {
    "ALA", "ARG", "ASN", "ASP", "CYS", "GLN", "GLU", "GLY", "HIS", "ILE",
    "LEU", "LYS", "MET", "PHE", "PRO", "SER", "THR", "TRP", "TYR", "VAL"
}

# Physicochemical properties dictionary
AA_PROPERTIES = {
    "ALA": [1.24, 0.62, 0.38, 0.05, 6.00, 1.42, 1.00],
    "ARG": [2.74, -2.53, 0.89, 0.93, 10.76, 0.98, 0.79],
    "ASN": [2.14, -0.78, 0.48, 0.54, 5.41, 0.89, 0.76],
    "ASP": [2.16, -0.90, 0.49, 0.52, 2.85, 0.85, 0.72],
    "CYS": [1.50, 0.29, 0.54, 0.79, 5.07, 0.77, 0.63],
    "GLN": [2.17, -0.85, 0.51, 0.70, 5.65, 1.11, 0.92],
    "GLU": [2.18, -0.74, 0.52, 0.67, 3.15, 1.09, 0.90],
    "GLY": [0.00, 0.48, 0.00, 0.00, 6.06, 0.57, 0.57],
    "HIS": [2.48, -0.40, 0.69, 0.95, 7.60, 1.00, 0.87],
    "ILE": [3.08, 1.25, 0.76, 0.90, 6.05, 1.00, 0.97],
    "LEU": [2.80, 1.22, 0.74, 0.92, 6.01, 1.34, 1.01],
    "LYS": [2.90, -2.25, 0.84, 0.93, 9.74, 1.00, 0.79],
    "MET": [2.67, 1.02, 0.72, 1.01, 5.74, 1.20, 0.97],
    "PHE": [2.58, 1.47, 0.78, 1.26, 5.48, 1.16, 0.95],
    "PRO": [1.95, 0.09, 0.64, 0.75, 6.30, 0.57, 0.55],
    "SER": [1.31, -0.28, 0.41, 0.68, 5.68, 0.77, 0.75],
    "THR": [1.50, -0.18, 0.44, 0.69, 5.60, 0.83, 0.78],
    "TRP": [3.07, 1.45, 0.81, 1.41, 5.89, 1.09, 0.92],
    "TYR": [2.67, 0.94, 0.76, 1.20, 5.64, 0.97, 0.90],
    "VAL": [2.50, 1.08, 0.71, 0.91, 6.00, 1.06, 0.93],
}

FEATURE_SIZE = len(next(iter(AA_PROPERTIES.values()))) + 1  # Add B-factor

def parse_pdb_with_sites(pdb_file):
    """
    Parses a PDB file to extract:
    - ATOM lines: Standard protein atoms (non-binding site)
    - SITE lines: Atoms that belong to a binding site
    """
    atom_positions = {}
    site_residues = set()
    residue_b_factors = {}
    residue_names = {}

    with open(pdb_file, "r") as file:
        for line in file:
            if line.startswith(("SITE", "ATOM")):
                try:
                    chain_id = line[21]
                    res_id_str = line[22:26].strip()
                    res_id = int(''.join(filter(str.isdigit, res_id_str)))
                    residue_name = line[17:20].strip()
                    atom_name = line[12:16].strip()
                    x, y, z = map(float, [line[30:38], line[38:46], line[46:54]])
                    b_factor = float(line[60:66].strip())

                    residue_key = (chain_id, res_id)
                    residue_names[residue_key] = residue_name

                    if residue_key not in residue_b_factors:
                        residue_b_factors[residue_key] = []
                    residue_b_factors[residue_key].append(b_factor)

                    if atom_name == "CA":
                        atom_positions[residue_key] = np.array([x, y, z])

                    if line.startswith("SITE"):
                        site_residues.add(residue_key)

                except ValueError:
                    continue

    return atom_positions, site_residues, residue_b_factors, residue_names


def compute_edges(residue_positions, cutoff=8.0):
    """
    Computes edges between residues based on Cα atom distances.
    Returns:
      - `edges`: List of (res1, res2) residue pairs within the cutoff.
      - `edge_features`: Tensor of pairwise distances.
    """
    edges = []
    edge_features = []

    residue_keys = list(residue_positions.keys())
    coords = np.array([residue_positions[rid] for rid in residue_keys])

    # Compute pairwise distance matrix
    dist_matrix = np.linalg.norm(coords[:, None] - coords[None, :], axis=-1)

    # Get pairs of residues within the cutoff distance
    i_idx, j_idx = np.where((dist_matrix <= cutoff) & (dist_matrix > 0))

    for i, j in zip(i_idx, j_idx):
        if i < j:
            edges.append((residue_keys[i], residue_keys[j]))
            edge_features.append([dist_matrix[i, j]])  # Store distance as feature

    return edges, torch.tensor(edge_features, dtype=torch.float)



FEATURE_SIZE = 8  # 7 physicochemical properties + 1 B-factor

def create_protein_graph(pdb_file):
    """
    Creates a PyTorch Geometric graph for a protein with node and edge features.
    """
    atom_positions, site_residues, residue_b_factors, residue_names = parse_pdb_with_sites(pdb_file)
    residue_features = []
    residue_labels = {}

    for res_id in atom_positions.keys():
        residue_name = residue_names.get(res_id, "UNK")
        binding_label = 1 if res_id in site_residues else -1
        residue_labels[res_id] = binding_label

        mean_b_factor = np.mean(residue_b_factors.get(res_id, [0.0]))

        # Get physicochemical properties or use zero vector
        features = AA_PROPERTIES.get(residue_name, [0] * (FEATURE_SIZE - 1))
        features.append(mean_b_factor)

        # Ensure fixed feature size
        if len(features) < FEATURE_SIZE:
            features += [0] * (FEATURE_SIZE - len(features))
        elif len(features) > FEATURE_SIZE:
            features = features[:FEATURE_SIZE]

        residue_features.append(features)

    # Convert labels to tensor
    node_labels = torch.tensor([residue_labels.get(rid, -1) for rid in atom_positions.keys()], dtype=torch.float)

    # **Compute edges and edge features**
    edges, edge_features = compute_edges(atom_positions)

    # Convert to PyG format
    residue_index = {rid: i for i, rid in enumerate(atom_positions.keys())}
    edge_index = torch.tensor([[residue_index[r1], residue_index[r2]] for r1, r2 in edges]).t()
    edge_attr = edge_features  # Edge distances

    # Convert features to tensor
    node_features = torch.tensor(residue_features, dtype=torch.float)

    return Data(x=node_features, edge_index=edge_index, edge_attr=edge_attr, y=node_labels), residue_index, residue_names

# %%
import pandas as pd
from tabulate import tabulate

def print_node_info(protein_graph, residue_index, residue_names, node_idx):
    """
    Pretty prints the feature and connectivity information for a specific node in the protein graph.

    :param protein_graph: PyTorch Geometric Data object
    :param residue_index: Dictionary mapping (chain_id, res_id) -> node index
    :param residue_names: List storing amino acid names indexed by node index
    :param node_idx: Index of the node (residue) to inspect
    """
    # Get feature vector for the node
    node_features = protein_graph.x[node_idx].tolist()

    # Extract residue metadata
    index_to_residue = {v: k for k, v in residue_index.items()}  # Reverse mapping
    chain_id, res_id = index_to_residue[node_idx]  # Get chain & position
    residue_name = residue_names[node_idx]  # Residue name

    # Extract different feature components
    hydrophobicity, polarity, charge = node_features[:3]
    one_hot_encoding = node_features[3:-1]  # All but last (one-hot encoded amino acids)
    binding_site = node_features[-1]  # Last feature is binding site category

    # Get neighbors (connected nodes)
    connected_nodes = protein_graph.edge_index[1][protein_graph.edge_index[0] == node_idx].tolist()

    # Prepare DataFrame for better visualization
    feature_names = ["Hydrophobicity", "Polarity", "Charge"] + AMINO_ACIDS + ["Binding Site Category"]
    feature_values = [hydrophobicity, polarity, charge] + one_hot_encoding + [binding_site]

    df = pd.DataFrame({"Feature": feature_names, "Value": feature_values})

    print(f"\n=== Residue Information for Node {node_idx} ===")
    print(f"Residue: {residue_name}  |  Chain: {chain_id}  |  Position: {res_id}")
    print("\nResidue Properties:\n")
    print(tabulate(df, headers="keys", tablefmt="fancy_grid"))

    print(f"\n🔗 Connected Residues (Neighbors): {connected_nodes}")

# Example Usage
node_index = 5  # Choose a node to inspect
print_node_info(protein_graph, residue_index, residue_names, node_index)
# Out:
# === Residue Information for Node 5 ===
# Residue: ILE  |  Chain: A  |  Position: 6
#
# Residue Properties:
#
# ╒════╤═══════════════════════╤═════════╕
# │    │ Feature               │   Value │
# ╞════╪═══════════════════════╪═════════╡
# │  0 │ Hydrophobicity        │       1 │
# ├────┼───────────────────────┼─────────┤
# │  1 │ Polarity              │       0 │
# ├────┼───────────────────────┼─────────┤
# │  2 │ Charge                │       0 │
# ├────┼───────────────────────┼─────────┤
# │  3 │ ALA                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │  4 │ ARG                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │  5 │ ASN                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │  6 │ ASP                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │  7 │ CYS                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │  8 │ GLN                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │  9 │ GLU                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │ 10 │ GLY                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │ 11 │ HIS                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │ 12 │ ILE                   │       1 │
# ├────┼───────────────────────┼─────────┤
# │ 13 │ LEU                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │ 14 │ LYS                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │ 15 │ MET                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │ 16 │ PHE                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │ 17 │ PRO                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │ 18 │ SER                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │ 19 │ THR                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │ 20 │ TRP                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │ 21 │ TYR                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │ 22 │ VAL                   │       0 │
# ├────┼───────────────────────┼─────────┤
# │ 23 │ Binding Site Category │       0 │
# ╘════╧═══════════════════════╧═════════╛
#
# 🔗 Connected Residues (Neighbors): [6, 7, 8, 9, 64, 73]

# %%
#pdb_file = "1uv6.pdb"
#protein_graph, _, _ = create_protein_graph(pdb_file) # Unpack the tuple to get the Data object

from torch_geometric.data import Dataset

class ProteinGraphDataset(Dataset):
    def __init__(self, pdb_files):
        super().__init__()
        self.pdb_files = pdb_files
        self.graphs = []
        self.max_features = FEATURE_SIZE  # Ensure consistency

        for pdb_file in pdb_files:
            try:
                graph = create_protein_graph(pdb_file)[0]  # Extract Data object

                # **Ensure node features match max feature size**
                if graph.x.shape[1] != self.max_features:
                    pad_size = self.max_features - graph.x.shape[1]
                    graph.x = torch.cat([graph.x, torch.zeros(graph.x.shape[0], pad_size)], dim=1)

                self.graphs.append(graph)
                print(f"✅ Successfully processed {pdb_file}")

            except Exception as e:
                print(f"❌ Error processing {pdb_file}: {e}")  # Catch and print errors

    def len(self):
        return len(self.graphs)

    def get(self, idx):
        return self.graphs[idx]


# Example usage

import os

# Define the directory where PDB files are stored
pdb_directory = "/content/proteins_extracted/protwithsite"  # Change this to your actual path

# Get all files with .pdb or .ent extension in the folder
pdb_files = [os.path.join(pdb_directory, f) for f in os.listdir(pdb_directory) if f.endswith((".pdb", ".ent"))]

# Create the dataset
dataset = ProteinGraphDataset(pdb_files)

print(f"Successfully loaded {len(dataset)} graphs.")


#print(protein_graph)
#print("Feature Matrix Shape:", protein_graph.x.shape)
#print("Number of Nodes:", protein_graph.x.shape[0])
#print("Number of Edges:", protein_graph.edge_index.shape[1])
# Out:
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4gkm_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/5aba_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4ivc_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1eby_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2c3i_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3ge7_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2weg_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4j28_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1q8t_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2j78_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2yfe_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3arq_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3ehy_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3wtj_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1bzc_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3jya_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3nq9_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1bcu_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2wn9_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4dli_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4ddk_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1nc1_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3uev_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3ui7_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3pxf_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3d6q_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4ea2_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3zsx_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3uex_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3kr8_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2qnq_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3tsk_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3dx1_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4abg_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2yki_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2xj7_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4crc_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1z6e_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4f2w_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3bgz_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1mq6_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2zb1_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2wvt_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3o9i_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4w9i_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3ueu_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3up2_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4pcs_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3b1m_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2zcq_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2xb8_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3udh_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3f3d_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2j7h_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2x00_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/5a7b_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4jfs_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3pyy_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4e5w_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2w4x_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3u5j_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4j21_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4kz6_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3fur_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3fv1_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4djv_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4ih7_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1ydt_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3g0w_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2br1_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2xii_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3g31_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3lka_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4cig_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3aru_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4gr0_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3rlr_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3myg_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4rfm_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3gy4_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3ao4_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3f3a_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3n76_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3twp_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3qgy_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3uew_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/5dwr_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4eor_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4f9w_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4m0y_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2qbr_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3acw_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3e92_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4w9h_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4tmn_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4mme_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4k18_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3dxg_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4f3c_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2vvn_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3r88_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2xbv_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3p5o_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2al5_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3zso_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3nw9_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3b65_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4jsz_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3wz8_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4ogj_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3ejr_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3ivg_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3coz_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1p1n_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4agq_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4ivb_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4kzu_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4gfm_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4eo8_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1z9g_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3k5v_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3nx7_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2iwx_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1h23_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3fcq_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3oe5_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2wnc_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2vw5_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1gpn_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3fv2_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1r5y_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2p4y_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1vso_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1syi_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2p15_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3gbb_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2v00_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4cra_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1pxn_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4ciw_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3u9q_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3n7a_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2w66_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2cet_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4qac_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3b5r_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3l7b_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2fvd_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3gv9_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4ddh_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2cbv_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3gc5_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4wiv_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4cr9_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1s38_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4e6q_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2xys_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2fxs_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2y5h_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2brb_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4twp_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2wca_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2zcr_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4u4s_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3ary_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1q8u_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3jvr_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4owm_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3uri_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3bv9_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3oe4_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3ag9_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4agn_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3u8k_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3n86_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/5c28_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4qd6_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3d4z_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3pww_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2vkm_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4m0z_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3ebp_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4de3_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2zy1_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1qf1_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/5tmn_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1owh_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1nc3_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1ydr_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4bkt_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3ozs_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4kzq_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1e66_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3dd0_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4lzs_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1k1i_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4w9l_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3e93_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1u1b_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2qbq_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3rr4_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3rsx_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1sqa_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1nvq_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1z95_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1o0h_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3cj4_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3qqs_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3arp_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3arv_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1qkt_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4agp_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2qbp_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3g2z_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3mss_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3zdg_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3ozt_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2ymd_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1p1q_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1o3f_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2qe4_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3gnw_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3syr_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4ih5_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3kgp_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4jia_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1w4o_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2pog_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4x6p_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1c5z_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3gr2_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3f3e_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4jxs_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3dx2_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4ivd_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3u8n_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3e5a_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4j3l_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3jvs_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4mgd_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4de2_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2wbg_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4eky_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2wer_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4dld_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1h22_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4ty7_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1gpk_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3zt2_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2r9w_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1y6r_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2zda_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1g2k_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3utu_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3coy_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4w9c_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2yge_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3ryj_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3uo4_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4f09_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3kwa_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3f3c_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4de1_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1yc1_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1ps3_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4llx_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1lpg_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2xdl_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3g2n_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2v7a_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3uuo_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2xnb_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/5c2h_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4gid_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1a30_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3prs_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1o5b_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1uto_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3b27_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/1oyt_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2hb1_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/2wtv_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/3b68_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4k77_protwithsite.pdb
# ✅ Successfully processed /content/proteins_extracted/protwithsite/4hge_protwithsite.pdb
# Successfully loaded 285 graphs.

# %%
pdb_file = "pdb3lb5.ent"
protein_graph, _, _ = create_protein_graph(pdb_file) # Unpack the tuple to get the Data object

# %%
import networkx as nx
import matplotlib.pyplot as plt
from torch_geometric.utils import to_networkx

def visualize_protein_graph(protein_graph, title="Protein Graph Visualization"):
    """
    Visualizes the protein graph using NetworkX and Matplotlib.
    Nodes are colored based on binding site labels.
    """
    # Convert PyTorch Geometric graph to NetworkX
    G = to_networkx(protein_graph, to_undirected=True)

    # Get node positions using a force-directed layout
    pos = nx.spring_layout(G, seed=42)

    # Extract binding site information from the node feature matrix
    binding_site_labels = protein_graph.y.numpy()

    # Define node colors:
    # - Non-binding residues (0) are blue
    # - Binding site residues (any other ID) are red
    node_colors = ["red" if label > 0 else "blue" for label in binding_site_labels]

    plt.figure(figsize=(8, 6))
    nx.draw(G, pos, node_color=node_colors, with_labels=False, node_size=50, edge_color="gray", alpha=0.6)

    # Legend
    plt.scatter([], [], color="blue", label="Non-binding Residues")
    plt.scatter([], [], color="red", label="Binding Site Residues")
    plt.legend(loc="upper right")

    plt.title(title)
    plt.show()

# Call the function to visualize the graph
visualize_protein_graph(protein_graph)

# %%
import networkx as nx
import matplotlib.pyplot as plt
from torch_geometric.utils import to_networkx

def visualize_graph(graph, title="Protein Graph"):
    """
    Converts a PyTorch Geometric graph to a networkx graph and plots it.
    Nodes are colored based on their binding site category.
    """
    G = to_networkx(graph, to_undirected=True)  # Convert to networkx
    plt.figure(figsize=(8, 6))

    # Node colors based on binding site category
    node_labels = graph.y.numpy()
    node_colors = ["red" if lbl > 0 else "blue" for lbl in node_labels]  # Binding sites = red

    nx.draw(G, with_labels=True, node_color=node_colors, node_size=100, font_size=8)
    plt.title(title)
    plt.show()

# Visualize the first graph in the dataset
visualize_graph(dataset.get(0), title=f"Graph for {dataset.pdb_files[0]}")

num_graphs = len(dataset)
cols = 3  # Set columns for the grid
rows = (num_graphs // cols) + (num_graphs % cols > 0)

fig, axes = plt.subplots(rows, cols, figsize=(15, 10))

for i, graph in enumerate(dataset):
    row, col = divmod(i, cols)
    ax = axes[row, col]

    G = to_networkx(graph, to_undirected=True)
    node_labels = graph.y.numpy()
    node_colors = ["red" if lbl > 0 else "blue" for lbl in node_labels]

    nx.draw(G, ax=ax, node_color=node_colors, node_size=100, font_size=6)
    ax.set_title(f"Graph {i+1}: {dataset.pdb_files[i]}")

# Hide empty subplots if dataset size < rows*cols
for j in range(i + 1, rows * cols):
    row, col = divmod(j, cols)
    fig.delaxes(axes[row, col])

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-fcf4204882d4> in <cell line: 0>()
#      26 rows = (num_graphs // cols) + (num_graphs % cols > 0)
#      27
# ---> 28 fig, axes = plt.subplots(rows, cols, figsize=(15, 10))
#      29
#      30 for i, graph in enumerate(dataset):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1774     """
#    1775     fig = figure(**fig_kw)
# -> 1776     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1777                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1778                        gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     917
#     918         gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
# --> 919         axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     920                           subplot_kw=subplot_kw)
#     921         return axs
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/gridspec.py in subplots(self, sharex, sharey, squeeze, subplot_kw)
#     281                 subplot_kw["sharex"] = shared_with[sharex]
#     282                 subplot_kw["sharey"] = shared_with[sharey]
# --> 283                 axarr[row, col] = figure.add_subplot(
#     284                     self[row, col], **subplot_kw)
#     285
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#     766                 args = tuple(map(int, str(args[0])))
#     767             projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 768             ax = projection_class(self, *args, **pkw)
#     769             key = (projection_class, pkw)
#     770         return self._add_axes_internal(ax, key)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in __init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     694
#     695         self._rasterization_zorder = None
# --> 696         self.clear()
#     697
#     698         # funcs used to format x and y - fall back on major formatters
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in clear(self)
#    1414             self.cla()
#    1415         else:
# -> 1416             self.__clear()
#    1417
#    1418     def cla(self):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in __clear(self)
#    1381         self.set_axis_on()
#    1382
# -> 1383         self.xaxis.set_clip_path(self.patch)
#    1384         self.yaxis.set_clip_path(self.patch)
#    1385
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in set_clip_path(self, path, transform)
#    1127         super().set_clip_path(path, transform)
#    1128         for child in self.majorTicks + self.minorTicks:
# -> 1129             child.set_clip_path(path, transform)
#    1130         self.stale = True
#    1131
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in set_clip_path(self, path, transform)
#     234     def set_clip_path(self, path, transform=None):
#     235         # docstring inherited
# --> 236         super().set_clip_path(path, transform)
#     237         self.gridline.set_clip_path(path, transform)
#     238         self.stale = True
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in set_clip_path(self, path, transform)
#     813             if isinstance(path, Rectangle):
#     814                 self.clipbox = TransformedBbox(Bbox.unit(),
# --> 815                                                path.get_transform())
#     816                 self._clippath = None
#     817                 success = True
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/patches.py in get_transform(self)
#     307     def get_transform(self):
#     308         """Return the `~.transforms.Transform` applied to the `Patch`."""
# --> 309         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     310
#     311     def get_data_transform(self):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/transforms.py in __add__(self, other)
#    1345         ``C.transform(x) == B.transform(A.transform(x))``.
#    1346         """
# -> 1347         return (composite_transform_factory(self, other)
#    1348                 if isinstance(other, Transform) else
#    1349                 NotImplemented)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/transforms.py in composite_transform_factory(a, b)
#    2520     elif isinstance(a, Affine2D) and isinstance(b, Affine2D):
#    2521         return CompositeAffine2D(a, b)
# -> 2522     return CompositeGenericTransform(a, b)
#    2523
#    2524
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/transforms.py in __init__(self, a, b, **kwargs)
#    2357         self._a = a
#    2358         self._b = b
# -> 2359         self.set_children(a, b)
#    2360
#    2361     def frozen(self):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/transforms.py in set_children(self, *children)
#     192             # alive; the callback deletes the dictionary entry. This is a
#     193             # performance improvement over using WeakValueDictionary.
# --> 194             ref = weakref.ref(
#     195                 self, lambda _, pop=child._parents.pop, k=id_self: pop(k))
#     196             child._parents[id_self] = ref
#
# KeyboardInterrupt:
# Error in callback <function _draw_all_if_interactive at 0x79b982edccc0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#     280
#     281
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     129         for manager in cls.get_all_fig_managers():
#     130             if force or manager.canvas.figure.stale:
# --> 131                 manager.canvas.draw_idle()
#     132
#     133
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1889         if not self._is_idle_drawing:
#    1890             with self._idle_draw_cntx():
# -> 1891                 self.draw(*args, **kwargs)
#    1892
#    1893     @property
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     380         with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381               else nullcontext()):
# --> 382             self.figure.draw(self.renderer)
#     383             # A GUI class may be need to update a window using this draw, so
#     384             # don't forget to call the superclass.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      92     @wraps(draw)
#      93     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94         result = draw(artist, renderer, *args, **kwargs)
#      95         if renderer._rasterizing:
#      96             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3255
#    3256                 self.patch.draw(renderer)
# -> 3257                 mimage._draw_list_compositing_images(
#    3258                     renderer, self, artists, self.suppressComposite)
#    3259
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3179             _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
#    3180
# -> 3181         mimage._draw_list_compositing_images(
#    3182             renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3183
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in draw(self, renderer)
#    1420
#    1421         # Shift label away from axes to avoid overlapping ticklabels.
# -> 1422         self._update_label_position(renderer)
#    1423         self.label.draw(renderer)
#    1424
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2463             # Union with extents of the bottom spine if present, of the axes otherwise.
#    2464             bbox = mtransforms.Bbox.union([
# -> 2465                 *bboxes, self.axes.spines.get("bottom", self.axes).get_window_extent()])
#    2466             self.label.set_position(
#    2467                 (x, bbox.y0 - self.labelpad * self.get_figure(root=True).dpi / 72))
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/spines.py in get_window_extent(self, renderer)
#     156             return bb
#     157         bboxes = [bb]
# --> 158         drawn_ticks = self.axis._update_ticks()
#     159
#     160         major_tick = next(iter({*drawn_ticks} & {*self.axis.majorTicks}), None)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in _update_ticks(self)
#    1297             tick.label1.set_text(label)
#    1298             tick.label2.set_text(label)
# -> 1299         minor_locs = self.get_minorticklocs()
#    1300         minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1301         minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in get_minorticklocs(self)
#    1541         minor_locs = np.asarray(self.minor.locator())
#    1542         if self.remove_overlapping_locs:
# -> 1543             major_locs = self.major.locator()
#    1544             transform = self._scale.get_transform()
#    1545             tr_minor_locs = transform.transform(minor_locs)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/ticker.py in __call__(self)
#    2226     def __call__(self):
#    2227         vmin, vmax = self.axis.get_view_interval()
# -> 2228         return self.tick_values(vmin, vmax)
#    2229
#    2230     def tick_values(self, vmin, vmax):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    2234         vmin, vmax = mtransforms.nonsingular(
#    2235             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2236         locs = self._raw_ticks(vmin, vmax)
#    2237
#    2238         prune = self._prune
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/ticker.py in _raw_ticks(self, vmin, vmax)
#    2164         if self._nbins == 'auto':
#    2165             if self.axis is not None:
# -> 2166                 nbins = np.clip(self.axis.get_tick_space(),
#    2167                                 max(1, self._min_n_ticks - 1), 9)
#    2168             else:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in get_tick_space(self)
#    2590
#    2591     def get_tick_space(self):
# -> 2592         ends = mtransforms.Bbox.unit().transformed(
#    2593             self.axes.transAxes - self.get_figure(root=False).dpi_scale_trans)
#    2594         length = ends.width * 72
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/transforms.py in unit()
#     786     def unit():
#     787         """Create a new unit `Bbox` from (0, 0) to (1, 1)."""
# --> 788         return Bbox([[0, 0], [1, 1]])
#     789
#     790     @staticmethod
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/transforms.py in __init__(self, points, **kwargs)
#     760                              '"[[x0, y0], [x1, y1]]".')
#     761         self._points = points
# --> 762         self._minpos = _default_minpos.copy()
#     763         self._ignore = True
#     764         # it is helpful in some contexts to know if the bbox is a
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x79b982ea2660> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.11/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182                 # force the figure dpi to 72), so we need to set it again here.
#    2183                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184                     result = print_method(
#    2185                         filename,
#    2186                         facecolor=facecolor,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2038                 "bbox_inches_restore"}
#    2039             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042         else:  # Let third-parties do as they see fit.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs)
#     479             *metadata*, including the default 'Software' key.
#     480         """
# --> 481         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     482
#     483     def print_to_buffer(self):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     427         *pil_kwargs* and *metadata* are forwarded).
#     428         """
# --> 429         FigureCanvasAgg.draw(self)
#     430         mpl.image.imsave(
#     431             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     380         with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381               else nullcontext()):
# --> 382             self.figure.draw(self.renderer)
#     383             # A GUI class may be need to update a window using this draw, so
#     384             # don't forget to call the superclass.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      92     @wraps(draw)
#      93     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94         result = draw(artist, renderer, *args, **kwargs)
#      95         if renderer._rasterizing:
#      96             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3255
#    3256                 self.patch.draw(renderer)
# -> 3257                 mimage._draw_list_compositing_images(
#    3258                     renderer, self, artists, self.suppressComposite)
#    3259
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3179             _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
#    3180
# -> 3181         mimage._draw_list_compositing_images(
#    3182             renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3183
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in draw(self, renderer)
#    1417
#    1418         for tick in ticks_to_draw:
# -> 1419             tick.draw(renderer)
#    1420
#    1421         # Shift label away from axes to avoid overlapping ticklabels.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in draw(self, renderer)
#     274         for artist in [self.gridline, self.tick1line, self.tick2line,
#     275                        self.label1, self.label2]:
# --> 276             artist.draw(renderer)
#     277         renderer.close_group(self.__name__)
#     278         self.stale = False
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/lines.py in draw(self, renderer)
#     750
#     751         if self._invalidy or self._invalidx:
# --> 752             self.recache()
#     753         self.ind_offset = 0  # Needed for contains() method.
#     754         if self._subslice and self.axes:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/lines.py in recache(self, always)
#     709             interpolation_steps = 1
#     710         xy = STEP_LOOKUP_MAP[self._drawstyle](*self._xy.T)
# --> 711         self._path = Path(np.asarray(xy).T,
#     712                           _interpolation_steps=interpolation_steps)
#     713         self._transformed_path = None
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     128         """
#     129         vertices = _to_unmasked_float_array(vertices)
# --> 130         _api.check_shape((None, 2), vertices=vertices)
#     131
#     132         if codes is not None and len(vertices):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/__init__.py in check_shape(shape, **kwargs)
#     151
#     152         if (len(data_shape) != len(shape)
# --> 153                 or any(s != t and t is not None for s, t in zip(data_shape, shape))):
#     154             dim_labels = iter(itertools.chain(
#     155                 'NMLKJIH',
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/__init__.py in <genexpr>(.0)
#     151
#     152         if (len(data_shape) != len(shape)
# --> 153                 or any(s != t and t is not None for s, t in zip(data_shape, shape))):
#     154             dim_labels = iter(itertools.chain(
#     155                 'NMLKJIH',
#
# KeyboardInterrupt:

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv, GCNConv
from torch_geometric.loader import DataLoader

class BindingSiteGNN(nn.Module):
    def __init__(self, in_dim, hidden_dim, out_dim, num_heads=3, num_layers=3):
        super(BindingSiteGNN, self).__init__()

        self.num_layers = num_layers

        # First layer: GAT with edge attributes
        self.conv1 = GATConv(in_channels=in_dim, out_channels=hidden_dim, heads=num_heads, concat=True, edge_dim=1)

        # Intermediate layers: Mix of GAT and GCN
        self.convs = nn.ModuleList()
        for _ in range(num_layers - 2):
            self.convs.append(GCNConv(hidden_dim * num_heads, hidden_dim))

        # Last layer: GAT with edge attributes
        self.conv_last = GATConv(hidden_dim, hidden_dim, heads=1, concat=False, edge_dim=1)

        # Fully connected layers for classification
        self.fc1 = nn.Linear(hidden_dim, hidden_dim // 2)
        self.dropout = nn.Dropout(0.3)
        self.fc2 = nn.Linear(hidden_dim // 2, out_dim)

    def forward(self, x, edge_index, edge_attr):
        x = self.conv1(x, edge_index, edge_attr)
        x = F.relu(x)

        for conv in self.convs:
            x = conv(x, edge_index)
            x = F.relu(x)

        x = self.conv_last(x, edge_index, edge_attr)
        x = F.relu(x)

        x = self.fc1(x)
        x = self.dropout(F.relu(x))
        x = self.fc2(x)

        return torch.sigmoid(x)



# Training Function
def train_model(model, train_loader, num_epochs=20, learning_rate=0.01):
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.BCELoss()

    model.train()
    for epoch in range(num_epochs):
        total_loss = 0
        for batch in train_loader:
            optimizer.zero_grad()
            output = model(batch.x, batch.edge_index, batch.edge_attr).squeeze()
            loss = criterion(output, (batch.y > 0).float())  # Convert to binary classification
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print(f"Epoch {epoch+1}, Loss: {total_loss / len(train_loader):.4f}")
    return model


# Evaluation Function
def evaluate_model(model, test_loader):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for batch in test_loader:
            output = model(batch.x, batch.edge_index, batch.edge_attr).squeeze()
            predicted = (output > 0.5).float()
            correct += (predicted == batch.y).sum().item()
            total += batch.y.size(0)
    print(f"Accuracy: {correct / total:.2f}")


# Ensure dataset is loaded before splitting
assert len(dataset) > 0, "Dataset is empty. Check if graphs were loaded correctly."

# Split dataset into train and test
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

# Create PyTorch Geometric DataLoaders
train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=2, shuffle=False)

# Determine input feature size dynamically
protein_graph = dataset[0]  # Get one graph to check feature size
in_dim = protein_graph.x.shape[1]

# Create and train model
model = BindingSiteGNN(in_dim=in_dim, hidden_dim=64, out_dim=1)
# Train the model
trained_model = train_model(model, train_loader)

# Save the trained model weights
torch.save(trained_model.state_dict(), "trained_model.pth")
print("✅ Model saved successfully as 'trained_model.pth'")

# Evaluate model
evaluate_model(trained_model, test_loader)
# Out:
# Epoch 1, Loss: 0.5084
# Epoch 2, Loss: 0.4845
# Epoch 3, Loss: 0.4818
# Epoch 4, Loss: 0.4794
# Epoch 5, Loss: 0.4775
# Epoch 6, Loss: 0.4799
# Epoch 7, Loss: 0.4799
# Epoch 8, Loss: 0.4716
# Epoch 9, Loss: 0.4711
# Epoch 10, Loss: 0.4631
# Epoch 11, Loss: 0.4645
# Epoch 12, Loss: 0.4593
# Epoch 13, Loss: 0.4693
# Epoch 14, Loss: 0.4656
# Epoch 15, Loss: 0.4606
# Epoch 16, Loss: 0.4699
# Epoch 17, Loss: 0.4600
# Epoch 18, Loss: 0.4568
# Epoch 19, Loss: 0.4709
# Epoch 20, Loss: 0.4704
# ✅ Model saved successfully as 'trained_model.pth'
# Accuracy: 0.00

# %%
import networkx as nx

def predict_binding_sites(model, pdb_file, threshold=0.2):
    model.eval()

    # ✅ Unpack protein graph
    protein_graph, residue_index, residue_names = create_protein_graph(pdb_file)

    # Get predictions
    with torch.no_grad():
        scores = model(protein_graph.x, protein_graph.edge_index, protein_graph.edge_attr).squeeze()

    # ✅ Store residues with binding probability > threshold
    predicted_residues = []
    for i, res_id in enumerate(residue_index.keys()):
        chain, res_num = res_id
        binding_prob = scores[i].item()
        if binding_prob > threshold:
            predicted_residues.append((chain, res_num, binding_prob))

    # ✅ Create a graph to cluster binding residues
    residue_graph = nx.Graph()
    for i, (chain1, res1, _) in enumerate(predicted_residues):
        for j, (chain2, res2, _) in enumerate(predicted_residues):
            if i < j and chain1 == chain2:
                if abs(res1 - res2) <= 5:  # Residues within 5 positions are connected
                    residue_graph.add_edge((chain1, res1), (chain2, res2))

    # ✅ Identify connected binding site clusters
    binding_sites = {}
    site_id = 1
    for component in nx.connected_components(residue_graph):
        binding_sites[site_id] = [(chain, res, score) for (chain, res, score) in predicted_residues if (chain, res) in component]
        site_id += 1

    return binding_sites  # 🔵 Now it returns a dictionary!

# %%
pdb_path = "1a3n.pdb"

# Dynamically get input dimension
in_dim = protein_graph.x.shape[1]
model = BindingSiteGNN(in_dim=in_dim, hidden_dim=64, out_dim=1)

# Predict binding sites
predicted_binding_sites = predict_binding_sites(model, pdb_path)

print("Predicted Binding Sites:")
for site_id, residues in predicted_binding_sites.items():
    print(f"Binding Site {site_id}:")
    for chain, res_id, score in residues:
        print(f"  Residue {res_id} in Chain {chain}: Binding Score = {score:.3f}")
# Out:
# Predicted Binding Sites:
# Binding Site 1:
#   Residue 1 in Chain A: Binding Score = 0.508
#   Residue 2 in Chain A: Binding Score = 0.509
#   Residue 3 in Chain A: Binding Score = 0.511
#   Residue 4 in Chain A: Binding Score = 0.513
#   Residue 5 in Chain A: Binding Score = 0.516
#   Residue 6 in Chain A: Binding Score = 0.515
#   Residue 7 in Chain A: Binding Score = 0.516
#   Residue 8 in Chain A: Binding Score = 0.520
#   Residue 9 in Chain A: Binding Score = 0.521
#   Residue 10 in Chain A: Binding Score = 0.521
#   Residue 11 in Chain A: Binding Score = 0.520
#   Residue 12 in Chain A: Binding Score = 0.519
#   Residue 13 in Chain A: Binding Score = 0.517
#   Residue 14 in Chain A: Binding Score = 0.517
#   Residue 15 in Chain A: Binding Score = 0.516
#   Residue 16 in Chain A: Binding Score = 0.516
#   Residue 17 in Chain A: Binding Score = 0.516
#   Residue 18 in Chain A: Binding Score = 0.516
#   Residue 19 in Chain A: Binding Score = 0.516
#   Residue 20 in Chain A: Binding Score = 0.516
#   Residue 21 in Chain A: Binding Score = 0.516
#   Residue 22 in Chain A: Binding Score = 0.517
#   Residue 23 in Chain A: Binding Score = 0.517
#   Residue 24 in Chain A: Binding Score = 0.518
#   Residue 25 in Chain A: Binding Score = 0.518
#   Residue 26 in Chain A: Binding Score = 0.518
#   Residue 27 in Chain A: Binding Score = 0.518
#   Residue 28 in Chain A: Binding Score = 0.518
#   Residue 29 in Chain A: Binding Score = 0.517
#   Residue 30 in Chain A: Binding Score = 0.517
#   Residue 31 in Chain A: Binding Score = 0.516
#   Residue 32 in Chain A: Binding Score = 0.516
#   Residue 33 in Chain A: Binding Score = 0.515
#   Residue 34 in Chain A: Binding Score = 0.514
#   Residue 35 in Chain A: Binding Score = 0.513
#   Residue 36 in Chain A: Binding Score = 0.512
#   Residue 37 in Chain A: Binding Score = 0.513
#   Residue 38 in Chain A: Binding Score = 0.513
#   Residue 39 in Chain A: Binding Score = 0.514
#   Residue 40 in Chain A: Binding Score = 0.515
#   Residue 41 in Chain A: Binding Score = 0.516
#   Residue 42 in Chain A: Binding Score = 0.517
#   Residue 43 in Chain A: Binding Score = 0.517
#   Residue 44 in Chain A: Binding Score = 0.517
#   Residue 45 in Chain A: Binding Score = 0.517
#   Residue 46 in Chain A: Binding Score = 0.518
#   Residue 47 in Chain A: Binding Score = 0.518
#   Residue 48 in Chain A: Binding Score = 0.517
#   Residue 49 in Chain A: Binding Score = 0.518
#   Residue 50 in Chain A: Binding Score = 0.517
#   Residue 51 in Chain A: Binding Score = 0.518
#   Residue 52 in Chain A: Binding Score = 0.519
#   Residue 53 in Chain A: Binding Score = 0.521
#   Residue 54 in Chain A: Binding Score = 0.520
#   Residue 55 in Chain A: Binding Score = 0.520
#   Residue 56 in Chain A: Binding Score = 0.521
#   Residue 57 in Chain A: Binding Score = 0.522
#   Residue 58 in Chain A: Binding Score = 0.521
#   Residue 59 in Chain A: Binding Score = 0.519
#   Residue 60 in Chain A: Binding Score = 0.520
#   Residue 61 in Chain A: Binding Score = 0.520
#   Residue 62 in Chain A: Binding Score = 0.519
#   Residue 63 in Chain A: Binding Score = 0.519
#   Residue 64 in Chain A: Binding Score = 0.519
#   Residue 65 in Chain A: Binding Score = 0.519
#   Residue 66 in Chain A: Binding Score = 0.518
#   Residue 67 in Chain A: Binding Score = 0.518
#   Residue 68 in Chain A: Binding Score = 0.518
#   Residue 69 in Chain A: Binding Score = 0.516
#   Residue 70 in Chain A: Binding Score = 0.517
#   Residue 71 in Chain A: Binding Score = 0.517
#   Residue 72 in Chain A: Binding Score = 0.517
#   Residue 73 in Chain A: Binding Score = 0.519
#   Residue 74 in Chain A: Binding Score = 0.517
#   Residue 75 in Chain A: Binding Score = 0.517
#   Residue 76 in Chain A: Binding Score = 0.517
#   Residue 77 in Chain A: Binding Score = 0.517
#   Residue 78 in Chain A: Binding Score = 0.518
#   Residue 79 in Chain A: Binding Score = 0.518
#   Residue 80 in Chain A: Binding Score = 0.519
#   Residue 81 in Chain A: Binding Score = 0.520
#   Residue 82 in Chain A: Binding Score = 0.520
#   Residue 83 in Chain A: Binding Score = 0.519
#   Residue 84 in Chain A: Binding Score = 0.519
#   Residue 85 in Chain A: Binding Score = 0.518
#   Residue 86 in Chain A: Binding Score = 0.518
#   Residue 87 in Chain A: Binding Score = 0.518
#   Residue 88 in Chain A: Binding Score = 0.518
#   Residue 89 in Chain A: Binding Score = 0.519
#   Residue 90 in Chain A: Binding Score = 0.519
#   Residue 91 in Chain A: Binding Score = 0.519
#   Residue 92 in Chain A: Binding Score = 0.519
#   Residue 93 in Chain A: Binding Score = 0.519
#   Residue 94 in Chain A: Binding Score = 0.517
#   Residue 95 in Chain A: Binding Score = 0.515
#   Residue 96 in Chain A: Binding Score = 0.515
#   Residue 97 in Chain A: Binding Score = 0.517
#   Residue 98 in Chain A: Binding Score = 0.517
#   Residue 99 in Chain A: Binding Score = 0.518
#   Residue 100 in Chain A: Binding Score = 0.518
#   Residue 101 in Chain A: Binding Score = 0.519
#   Residue 102 in Chain A: Binding Score = 0.519
#   Residue 103 in Chain A: Binding Score = 0.518
#   Residue 104 in Chain A: Binding Score = 0.516
#   Residue 105 in Chain A: Binding Score = 0.517
#   Residue 106 in Chain A: Binding Score = 0.516
#   Residue 107 in Chain A: Binding Score = 0.516
#   Residue 108 in Chain A: Binding Score = 0.517
#   Residue 109 in Chain A: Binding Score = 0.517
#   Residue 110 in Chain A: Binding Score = 0.515
#   Residue 111 in Chain A: Binding Score = 0.515
#   Residue 112 in Chain A: Binding Score = 0.515
#   Residue 113 in Chain A: Binding Score = 0.515
#   Residue 114 in Chain A: Binding Score = 0.514
#   Residue 115 in Chain A: Binding Score = 0.516
#   Residue 116 in Chain A: Binding Score = 0.516
#   Residue 117 in Chain A: Binding Score = 0.516
#   Residue 118 in Chain A: Binding Score = 0.518
#   Residue 119 in Chain A: Binding Score = 0.517
#   Residue 120 in Chain A: Binding Score = 0.518
#   Residue 121 in Chain A: Binding Score = 0.519
#   Residue 122 in Chain A: Binding Score = 0.518
#   Residue 123 in Chain A: Binding Score = 0.518
#   Residue 124 in Chain A: Binding Score = 0.519
#   Residue 125 in Chain A: Binding Score = 0.520
#   Residue 126 in Chain A: Binding Score = 0.518
#   Residue 127 in Chain A: Binding Score = 0.517
#   Residue 128 in Chain A: Binding Score = 0.518
#   Residue 129 in Chain A: Binding Score = 0.517
#   Residue 130 in Chain A: Binding Score = 0.517
#   Residue 131 in Chain A: Binding Score = 0.516
#   Residue 132 in Chain A: Binding Score = 0.517
#   Residue 133 in Chain A: Binding Score = 0.517
#   Residue 134 in Chain A: Binding Score = 0.517
#   Residue 135 in Chain A: Binding Score = 0.519
#   Residue 136 in Chain A: Binding Score = 0.520
#   Residue 137 in Chain A: Binding Score = 0.520
#   Residue 138 in Chain A: Binding Score = 0.520
#   Residue 139 in Chain A: Binding Score = 0.520
#   Residue 140 in Chain A: Binding Score = 0.520
#   Residue 141 in Chain A: Binding Score = 0.519
# Binding Site 2:
#   Residue 2 in Chain B: Binding Score = 0.519
#   Residue 3 in Chain B: Binding Score = 0.519
#   Residue 4 in Chain B: Binding Score = 0.520
#   Residue 5 in Chain B: Binding Score = 0.520
#   Residue 6 in Chain B: Binding Score = 0.520
#   Residue 7 in Chain B: Binding Score = 0.520
#   Residue 8 in Chain B: Binding Score = 0.520
#   Residue 9 in Chain B: Binding Score = 0.519
#   Residue 10 in Chain B: Binding Score = 0.518
#   Residue 11 in Chain B: Binding Score = 0.517
#   Residue 12 in Chain B: Binding Score = 0.516
#   Residue 13 in Chain B: Binding Score = 0.515
#   Residue 14 in Chain B: Binding Score = 0.515
#   Residue 15 in Chain B: Binding Score = 0.515
#   Residue 16 in Chain B: Binding Score = 0.516
#   Residue 17 in Chain B: Binding Score = 0.516
#   Residue 18 in Chain B: Binding Score = 0.516
#   Residue 19 in Chain B: Binding Score = 0.515
#   Residue 20 in Chain B: Binding Score = 0.514
#   Residue 21 in Chain B: Binding Score = 0.514
#   Residue 22 in Chain B: Binding Score = 0.514
#   Residue 23 in Chain B: Binding Score = 0.515
#   Residue 24 in Chain B: Binding Score = 0.515
#   Residue 25 in Chain B: Binding Score = 0.516
#   Residue 26 in Chain B: Binding Score = 0.516
#   Residue 27 in Chain B: Binding Score = 0.516
#   Residue 28 in Chain B: Binding Score = 0.516
#   Residue 29 in Chain B: Binding Score = 0.517
#   Residue 30 in Chain B: Binding Score = 0.517
#   Residue 31 in Chain B: Binding Score = 0.518
#   Residue 32 in Chain B: Binding Score = 0.517
#   Residue 33 in Chain B: Binding Score = 0.518
#   Residue 34 in Chain B: Binding Score = 0.519
#   Residue 35 in Chain B: Binding Score = 0.518
#   Residue 36 in Chain B: Binding Score = 0.518
#   Residue 37 in Chain B: Binding Score = 0.515
#   Residue 38 in Chain B: Binding Score = 0.516
#   Residue 39 in Chain B: Binding Score = 0.515
#   Residue 40 in Chain B: Binding Score = 0.516
#   Residue 41 in Chain B: Binding Score = 0.516
#   Residue 42 in Chain B: Binding Score = 0.517
#   Residue 43 in Chain B: Binding Score = 0.517
#   Residue 44 in Chain B: Binding Score = 0.516
#   Residue 45 in Chain B: Binding Score = 0.516
#   Residue 46 in Chain B: Binding Score = 0.516
#   Residue 47 in Chain B: Binding Score = 0.516
#   Residue 48 in Chain B: Binding Score = 0.516
#   Residue 49 in Chain B: Binding Score = 0.516
#   Residue 50 in Chain B: Binding Score = 0.519
#   Residue 51 in Chain B: Binding Score = 0.518
#   Residue 52 in Chain B: Binding Score = 0.518
#   Residue 53 in Chain B: Binding Score = 0.518
#   Residue 54 in Chain B: Binding Score = 0.519
#   Residue 55 in Chain B: Binding Score = 0.520
#   Residue 56 in Chain B: Binding Score = 0.521
#   Residue 57 in Chain B: Binding Score = 0.519
#   Residue 58 in Chain B: Binding Score = 0.518
#   Residue 59 in Chain B: Binding Score = 0.518
#   Residue 60 in Chain B: Binding Score = 0.519
#   Residue 61 in Chain B: Binding Score = 0.519
#   Residue 62 in Chain B: Binding Score = 0.520
#   Residue 63 in Chain B: Binding Score = 0.520
#   Residue 64 in Chain B: Binding Score = 0.519
#   Residue 65 in Chain B: Binding Score = 0.519
#   Residue 66 in Chain B: Binding Score = 0.519
#   Residue 67 in Chain B: Binding Score = 0.520
#   Residue 68 in Chain B: Binding Score = 0.518
#   Residue 69 in Chain B: Binding Score = 0.517
#   Residue 70 in Chain B: Binding Score = 0.518
#   Residue 71 in Chain B: Binding Score = 0.517
#   Residue 72 in Chain B: Binding Score = 0.517
#   Residue 73 in Chain B: Binding Score = 0.517
#   Residue 74 in Chain B: Binding Score = 0.516
#   Residue 75 in Chain B: Binding Score = 0.517
#   Residue 76 in Chain B: Binding Score = 0.518
#   Residue 77 in Chain B: Binding Score = 0.518
#   Residue 78 in Chain B: Binding Score = 0.519
#   Residue 79 in Chain B: Binding Score = 0.518
#   Residue 80 in Chain B: Binding Score = 0.518
#   Residue 81 in Chain B: Binding Score = 0.519
#   Residue 82 in Chain B: Binding Score = 0.518
#   Residue 83 in Chain B: Binding Score = 0.518
#   Residue 84 in Chain B: Binding Score = 0.519
#   Residue 85 in Chain B: Binding Score = 0.519
#   Residue 86 in Chain B: Binding Score = 0.519
#   Residue 87 in Chain B: Binding Score = 0.519
#   Residue 88 in Chain B: Binding Score = 0.517
#   Residue 89 in Chain B: Binding Score = 0.517
#   Residue 90 in Chain B: Binding Score = 0.516
#   Residue 91 in Chain B: Binding Score = 0.516
#   Residue 92 in Chain B: Binding Score = 0.516
#   Residue 93 in Chain B: Binding Score = 0.516
#   Residue 94 in Chain B: Binding Score = 0.516
#   Residue 95 in Chain B: Binding Score = 0.516
#   Residue 96 in Chain B: Binding Score = 0.516
#   Residue 97 in Chain B: Binding Score = 0.517
#   Residue 98 in Chain B: Binding Score = 0.517
#   Residue 99 in Chain B: Binding Score = 0.517
#   Residue 100 in Chain B: Binding Score = 0.517
#   Residue 101 in Chain B: Binding Score = 0.516
#   Residue 102 in Chain B: Binding Score = 0.517
#   Residue 103 in Chain B: Binding Score = 0.518
#   Residue 104 in Chain B: Binding Score = 0.518
#   Residue 105 in Chain B: Binding Score = 0.518
#   Residue 106 in Chain B: Binding Score = 0.518
#   Residue 107 in Chain B: Binding Score = 0.519
#   Residue 108 in Chain B: Binding Score = 0.517
#   Residue 109 in Chain B: Binding Score = 0.517
#   Residue 110 in Chain B: Binding Score = 0.517
#   Residue 111 in Chain B: Binding Score = 0.516
#   Residue 112 in Chain B: Binding Score = 0.515
#   Residue 113 in Chain B: Binding Score = 0.516
#   Residue 114 in Chain B: Binding Score = 0.515
#   Residue 115 in Chain B: Binding Score = 0.515
#   Residue 116 in Chain B: Binding Score = 0.515
#   Residue 117 in Chain B: Binding Score = 0.515
#   Residue 118 in Chain B: Binding Score = 0.514
#   Residue 119 in Chain B: Binding Score = 0.515
#   Residue 120 in Chain B: Binding Score = 0.515
#   Residue 121 in Chain B: Binding Score = 0.515
#   Residue 122 in Chain B: Binding Score = 0.515
#   Residue 123 in Chain B: Binding Score = 0.515
#   Residue 124 in Chain B: Binding Score = 0.514
#   Residue 125 in Chain B: Binding Score = 0.515
#   Residue 126 in Chain B: Binding Score = 0.516
#   Residue 127 in Chain B: Binding Score = 0.515
#   Residue 128 in Chain B: Binding Score = 0.515
#   Residue 129 in Chain B: Binding Score = 0.517
#   Residue 130 in Chain B: Binding Score = 0.517
#   Residue 131 in Chain B: Binding Score = 0.516
#   Residue 132 in Chain B: Binding Score = 0.518
#   Residue 133 in Chain B: Binding Score = 0.519
#   Residue 134 in Chain B: Binding Score = 0.518
#   Residue 135 in Chain B: Binding Score = 0.518
#   Residue 136 in Chain B: Binding Score = 0.518
#   Residue 137 in Chain B: Binding Score = 0.518
#   Residue 138 in Chain B: Binding Score = 0.518
#   Residue 139 in Chain B: Binding Score = 0.517
#   Residue 140 in Chain B: Binding Score = 0.519
#   Residue 141 in Chain B: Binding Score = 0.519
#   Residue 142 in Chain B: Binding Score = 0.519
#   Residue 143 in Chain B: Binding Score = 0.519
#   Residue 144 in Chain B: Binding Score = 0.519
#   Residue 145 in Chain B: Binding Score = 0.518
#   Residue 146 in Chain B: Binding Score = 0.517
# Binding Site 3:
#   Residue 1 in Chain C: Binding Score = 0.517
#   Residue 2 in Chain C: Binding Score = 0.512
#   Residue 3 in Chain C: Binding Score = 0.512
#   Residue 4 in Chain C: Binding Score = 0.513
#   Residue 5 in Chain C: Binding Score = 0.514
#   Residue 6 in Chain C: Binding Score = 0.515
#   Residue 7 in Chain C: Binding Score = 0.516
#   Residue 8 in Chain C: Binding Score = 0.519
#   Residue 9 in Chain C: Binding Score = 0.519
#   Residue 10 in Chain C: Binding Score = 0.519
#   Residue 11 in Chain C: Binding Score = 0.519
#   Residue 12 in Chain C: Binding Score = 0.518
#   Residue 13 in Chain C: Binding Score = 0.517
#   Residue 14 in Chain C: Binding Score = 0.516
#   Residue 15 in Chain C: Binding Score = 0.517
#   Residue 16 in Chain C: Binding Score = 0.516
#   Residue 17 in Chain C: Binding Score = 0.516
#   Residue 18 in Chain C: Binding Score = 0.516
#   Residue 19 in Chain C: Binding Score = 0.515
#   Residue 20 in Chain C: Binding Score = 0.516
#   Residue 21 in Chain C: Binding Score = 0.516
#   Residue 22 in Chain C: Binding Score = 0.517
#   Residue 23 in Chain C: Binding Score = 0.518
#   Residue 24 in Chain C: Binding Score = 0.518
#   Residue 25 in Chain C: Binding Score = 0.518
#   Residue 26 in Chain C: Binding Score = 0.519
#   Residue 27 in Chain C: Binding Score = 0.518
#   Residue 28 in Chain C: Binding Score = 0.518
#   Residue 29 in Chain C: Binding Score = 0.517
#   Residue 30 in Chain C: Binding Score = 0.517
#   Residue 31 in Chain C: Binding Score = 0.516
#   Residue 32 in Chain C: Binding Score = 0.516
#   Residue 33 in Chain C: Binding Score = 0.515
#   Residue 34 in Chain C: Binding Score = 0.514
#   Residue 35 in Chain C: Binding Score = 0.513
#   Residue 36 in Chain C: Binding Score = 0.512
#   Residue 37 in Chain C: Binding Score = 0.514
#   Residue 38 in Chain C: Binding Score = 0.516
#   Residue 39 in Chain C: Binding Score = 0.516
#   Residue 40 in Chain C: Binding Score = 0.517
#   Residue 41 in Chain C: Binding Score = 0.518
#   Residue 42 in Chain C: Binding Score = 0.518
#   Residue 43 in Chain C: Binding Score = 0.518
#   Residue 44 in Chain C: Binding Score = 0.518
#   Residue 45 in Chain C: Binding Score = 0.517
#   Residue 46 in Chain C: Binding Score = 0.517
#   Residue 47 in Chain C: Binding Score = 0.518
#   Residue 48 in Chain C: Binding Score = 0.518
#   Residue 49 in Chain C: Binding Score = 0.518
#   Residue 50 in Chain C: Binding Score = 0.517
#   Residue 51 in Chain C: Binding Score = 0.518
#   Residue 52 in Chain C: Binding Score = 0.519
#   Residue 53 in Chain C: Binding Score = 0.521
#   Residue 54 in Chain C: Binding Score = 0.520
#   Residue 55 in Chain C: Binding Score = 0.520
#   Residue 56 in Chain C: Binding Score = 0.521
#   Residue 57 in Chain C: Binding Score = 0.521
#   Residue 58 in Chain C: Binding Score = 0.521
#   Residue 59 in Chain C: Binding Score = 0.520
#   Residue 60 in Chain C: Binding Score = 0.520
#   Residue 61 in Chain C: Binding Score = 0.520
#   Residue 62 in Chain C: Binding Score = 0.520
#   Residue 63 in Chain C: Binding Score = 0.520
#   Residue 64 in Chain C: Binding Score = 0.519
#   Residue 65 in Chain C: Binding Score = 0.519
#   Residue 66 in Chain C: Binding Score = 0.518
#   Residue 67 in Chain C: Binding Score = 0.518
#   Residue 68 in Chain C: Binding Score = 0.518
#   Residue 69 in Chain C: Binding Score = 0.516
#   Residue 70 in Chain C: Binding Score = 0.517
#   Residue 71 in Chain C: Binding Score = 0.517
#   Residue 72 in Chain C: Binding Score = 0.517
#   Residue 73 in Chain C: Binding Score = 0.519
#   Residue 74 in Chain C: Binding Score = 0.516
#   Residue 75 in Chain C: Binding Score = 0.516
#   Residue 76 in Chain C: Binding Score = 0.517
#   Residue 77 in Chain C: Binding Score = 0.517
#   Residue 78 in Chain C: Binding Score = 0.518
#   Residue 79 in Chain C: Binding Score = 0.518
#   Residue 80 in Chain C: Binding Score = 0.519
#   Residue 81 in Chain C: Binding Score = 0.520
#   Residue 82 in Chain C: Binding Score = 0.520
#   Residue 83 in Chain C: Binding Score = 0.519
#   Residue 84 in Chain C: Binding Score = 0.519
#   Residue 85 in Chain C: Binding Score = 0.518
#   Residue 86 in Chain C: Binding Score = 0.518
#   Residue 87 in Chain C: Binding Score = 0.518
#   Residue 88 in Chain C: Binding Score = 0.518
#   Residue 89 in Chain C: Binding Score = 0.518
#   Residue 90 in Chain C: Binding Score = 0.519
#   Residue 91 in Chain C: Binding Score = 0.519
#   Residue 92 in Chain C: Binding Score = 0.519
#   Residue 93 in Chain C: Binding Score = 0.519
#   Residue 94 in Chain C: Binding Score = 0.518
#   Residue 95 in Chain C: Binding Score = 0.518
#   Residue 96 in Chain C: Binding Score = 0.517
#   Residue 97 in Chain C: Binding Score = 0.518
#   Residue 98 in Chain C: Binding Score = 0.517
#   Residue 99 in Chain C: Binding Score = 0.517
#   Residue 100 in Chain C: Binding Score = 0.517
#   Residue 101 in Chain C: Binding Score = 0.518
#   Residue 102 in Chain C: Binding Score = 0.518
#   Residue 103 in Chain C: Binding Score = 0.517
#   Residue 104 in Chain C: Binding Score = 0.516
#   Residue 105 in Chain C: Binding Score = 0.517
#   Residue 106 in Chain C: Binding Score = 0.516
#   Residue 107 in Chain C: Binding Score = 0.516
#   Residue 108 in Chain C: Binding Score = 0.517
#   Residue 109 in Chain C: Binding Score = 0.517
#   Residue 110 in Chain C: Binding Score = 0.515
#   Residue 111 in Chain C: Binding Score = 0.515
#   Residue 112 in Chain C: Binding Score = 0.515
#   Residue 113 in Chain C: Binding Score = 0.515
#   Residue 114 in Chain C: Binding Score = 0.514
#   Residue 115 in Chain C: Binding Score = 0.515
#   Residue 116 in Chain C: Binding Score = 0.516
#   Residue 117 in Chain C: Binding Score = 0.516
#   Residue 118 in Chain C: Binding Score = 0.517
#   Residue 119 in Chain C: Binding Score = 0.517
#   Residue 120 in Chain C: Binding Score = 0.518
#   Residue 121 in Chain C: Binding Score = 0.518
#   Residue 122 in Chain C: Binding Score = 0.518
#   Residue 123 in Chain C: Binding Score = 0.518
#   Residue 124 in Chain C: Binding Score = 0.518
#   Residue 125 in Chain C: Binding Score = 0.519
#   Residue 126 in Chain C: Binding Score = 0.518
#   Residue 127 in Chain C: Binding Score = 0.518
#   Residue 128 in Chain C: Binding Score = 0.518
#   Residue 129 in Chain C: Binding Score = 0.518
#   Residue 130 in Chain C: Binding Score = 0.517
#   Residue 131 in Chain C: Binding Score = 0.516
#   Residue 132 in Chain C: Binding Score = 0.517
#   Residue 133 in Chain C: Binding Score = 0.517
#   Residue 134 in Chain C: Binding Score = 0.517
#   Residue 135 in Chain C: Binding Score = 0.519
#   Residue 136 in Chain C: Binding Score = 0.519
#   Residue 137 in Chain C: Binding Score = 0.519
#   Residue 138 in Chain C: Binding Score = 0.518
#   Residue 139 in Chain C: Binding Score = 0.518
#   Residue 140 in Chain C: Binding Score = 0.519
#   Residue 141 in Chain C: Binding Score = 0.518
# Binding Site 4:
#   Residue 2 in Chain D: Binding Score = 0.519
#   Residue 3 in Chain D: Binding Score = 0.519
#   Residue 4 in Chain D: Binding Score = 0.520
#   Residue 5 in Chain D: Binding Score = 0.520
#   Residue 6 in Chain D: Binding Score = 0.520
#   Residue 7 in Chain D: Binding Score = 0.520
#   Residue 8 in Chain D: Binding Score = 0.520
#   Residue 9 in Chain D: Binding Score = 0.519
#   Residue 10 in Chain D: Binding Score = 0.518
#   Residue 11 in Chain D: Binding Score = 0.517
#   Residue 12 in Chain D: Binding Score = 0.516
#   Residue 13 in Chain D: Binding Score = 0.515
#   Residue 14 in Chain D: Binding Score = 0.515
#   Residue 15 in Chain D: Binding Score = 0.515
#   Residue 16 in Chain D: Binding Score = 0.516
#   Residue 17 in Chain D: Binding Score = 0.516
#   Residue 18 in Chain D: Binding Score = 0.516
#   Residue 19 in Chain D: Binding Score = 0.515
#   Residue 20 in Chain D: Binding Score = 0.514
#   Residue 21 in Chain D: Binding Score = 0.514
#   Residue 22 in Chain D: Binding Score = 0.514
#   Residue 23 in Chain D: Binding Score = 0.515
#   Residue 24 in Chain D: Binding Score = 0.515
#   Residue 25 in Chain D: Binding Score = 0.516
#   Residue 26 in Chain D: Binding Score = 0.516
#   Residue 27 in Chain D: Binding Score = 0.516
#   Residue 28 in Chain D: Binding Score = 0.516
#   Residue 29 in Chain D: Binding Score = 0.517
#   Residue 30 in Chain D: Binding Score = 0.517
#   Residue 31 in Chain D: Binding Score = 0.518
#   Residue 32 in Chain D: Binding Score = 0.517
#   Residue 33 in Chain D: Binding Score = 0.518
#   Residue 34 in Chain D: Binding Score = 0.519
#   Residue 35 in Chain D: Binding Score = 0.519
#   Residue 36 in Chain D: Binding Score = 0.519
#   Residue 37 in Chain D: Binding Score = 0.519
#   Residue 38 in Chain D: Binding Score = 0.518
#   Residue 39 in Chain D: Binding Score = 0.517
#   Residue 40 in Chain D: Binding Score = 0.519
#   Residue 41 in Chain D: Binding Score = 0.515
#   Residue 42 in Chain D: Binding Score = 0.516
#   Residue 43 in Chain D: Binding Score = 0.516
#   Residue 44 in Chain D: Binding Score = 0.515
#   Residue 45 in Chain D: Binding Score = 0.515
#   Residue 46 in Chain D: Binding Score = 0.515
#   Residue 47 in Chain D: Binding Score = 0.516
#   Residue 48 in Chain D: Binding Score = 0.516
#   Residue 49 in Chain D: Binding Score = 0.516
#   Residue 50 in Chain D: Binding Score = 0.519
#   Residue 51 in Chain D: Binding Score = 0.518
#   Residue 52 in Chain D: Binding Score = 0.519
#   Residue 53 in Chain D: Binding Score = 0.518
#   Residue 54 in Chain D: Binding Score = 0.519
#   Residue 55 in Chain D: Binding Score = 0.520
#   Residue 56 in Chain D: Binding Score = 0.521
#   Residue 57 in Chain D: Binding Score = 0.519
#   Residue 58 in Chain D: Binding Score = 0.518
#   Residue 59 in Chain D: Binding Score = 0.518
#   Residue 60 in Chain D: Binding Score = 0.519
#   Residue 61 in Chain D: Binding Score = 0.519
#   Residue 62 in Chain D: Binding Score = 0.520
#   Residue 63 in Chain D: Binding Score = 0.520
#   Residue 64 in Chain D: Binding Score = 0.519
#   Residue 65 in Chain D: Binding Score = 0.519
#   Residue 66 in Chain D: Binding Score = 0.520
#   Residue 67 in Chain D: Binding Score = 0.519
#   Residue 68 in Chain D: Binding Score = 0.518
#   Residue 69 in Chain D: Binding Score = 0.517
#   Residue 70 in Chain D: Binding Score = 0.518
#   Residue 71 in Chain D: Binding Score = 0.518
#   Residue 72 in Chain D: Binding Score = 0.517
#   Residue 73 in Chain D: Binding Score = 0.517
#   Residue 74 in Chain D: Binding Score = 0.516
#   Residue 75 in Chain D: Binding Score = 0.517
#   Residue 76 in Chain D: Binding Score = 0.518
#   Residue 77 in Chain D: Binding Score = 0.518
#   Residue 78 in Chain D: Binding Score = 0.519
#   Residue 79 in Chain D: Binding Score = 0.518
#   Residue 80 in Chain D: Binding Score = 0.518
#   Residue 81 in Chain D: Binding Score = 0.519
#   Residue 82 in Chain D: Binding Score = 0.518
#   Residue 83 in Chain D: Binding Score = 0.518
#   Residue 84 in Chain D: Binding Score = 0.519
#   Residue 85 in Chain D: Binding Score = 0.519
#   Residue 86 in Chain D: Binding Score = 0.519
#   Residue 87 in Chain D: Binding Score = 0.519
#   Residue 88 in Chain D: Binding Score = 0.517
#   Residue 89 in Chain D: Binding Score = 0.517
#   Residue 90 in Chain D: Binding Score = 0.516
#   Residue 91 in Chain D: Binding Score = 0.516
#   Residue 92 in Chain D: Binding Score = 0.516
#   Residue 93 in Chain D: Binding Score = 0.517
#   Residue 94 in Chain D: Binding Score = 0.516
#   Residue 95 in Chain D: Binding Score = 0.516
#   Residue 96 in Chain D: Binding Score = 0.516
#   Residue 97 in Chain D: Binding Score = 0.517
#   Residue 98 in Chain D: Binding Score = 0.518
#   Residue 99 in Chain D: Binding Score = 0.517
#   Residue 100 in Chain D: Binding Score = 0.517
#   Residue 101 in Chain D: Binding Score = 0.517
#   Residue 102 in Chain D: Binding Score = 0.517
#   Residue 103 in Chain D: Binding Score = 0.517
#   Residue 104 in Chain D: Binding Score = 0.517
#   Residue 105 in Chain D: Binding Score = 0.518
#   Residue 106 in Chain D: Binding Score = 0.518
#   Residue 107 in Chain D: Binding Score = 0.517
#   Residue 108 in Chain D: Binding Score = 0.517
#   Residue 109 in Chain D: Binding Score = 0.517
#   Residue 110 in Chain D: Binding Score = 0.517
#   Residue 111 in Chain D: Binding Score = 0.516
#   Residue 112 in Chain D: Binding Score = 0.515
#   Residue 113 in Chain D: Binding Score = 0.516
#   Residue 114 in Chain D: Binding Score = 0.515
#   Residue 115 in Chain D: Binding Score = 0.515
#   Residue 116 in Chain D: Binding Score = 0.515
#   Residue 117 in Chain D: Binding Score = 0.515
#   Residue 118 in Chain D: Binding Score = 0.514
#   Residue 119 in Chain D: Binding Score = 0.515
#   Residue 120 in Chain D: Binding Score = 0.515
#   Residue 121 in Chain D: Binding Score = 0.515
#   Residue 122 in Chain D: Binding Score = 0.515
#   Residue 123 in Chain D: Binding Score = 0.515
#   Residue 124 in Chain D: Binding Score = 0.514
#   Residue 125 in Chain D: Binding Score = 0.514
#   Residue 126 in Chain D: Binding Score = 0.516
#   Residue 127 in Chain D: Binding Score = 0.515
#   Residue 128 in Chain D: Binding Score = 0.515
#   Residue 129 in Chain D: Binding Score = 0.517
#   Residue 130 in Chain D: Binding Score = 0.517
#   Residue 131 in Chain D: Binding Score = 0.516
#   Residue 132 in Chain D: Binding Score = 0.518
#   Residue 133 in Chain D: Binding Score = 0.519
#   Residue 134 in Chain D: Binding Score = 0.517
#   Residue 135 in Chain D: Binding Score = 0.517
#   Residue 136 in Chain D: Binding Score = 0.518
#   Residue 137 in Chain D: Binding Score = 0.517
#   Residue 138 in Chain D: Binding Score = 0.517
#   Residue 139 in Chain D: Binding Score = 0.517
#   Residue 140 in Chain D: Binding Score = 0.518
#   Residue 141 in Chain D: Binding Score = 0.518
#   Residue 142 in Chain D: Binding Score = 0.519
#   Residue 143 in Chain D: Binding Score = 0.518
#   Residue 144 in Chain D: Binding Score = 0.518
#   Residue 145 in Chain D: Binding Score = 0.517
#   Residue 146 in Chain D: Binding Score = 0.517
